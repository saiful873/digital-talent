# %%
import pandas as pd

# %%
data_amh = pd.read_csv('processed-angka-melek-huruf-usia-15-24-2005-2009.csv', delimiter = ',', encoding = "ISO-8859-1")

# %%
data_amh
# Out:
#       kode_provinsi                   nama_provinsi  kode_kabkota  \
# 0                11  Prov. Nanggroe Aceh Darussalam          1101
# 1                11  Prov. Nanggroe Aceh Darussalam          1101
# 2                11  Prov. Nanggroe Aceh Darussalam          1101
# 3                11  Prov. Nanggroe Aceh Darussalam          1101
# 4                11  Prov. Nanggroe Aceh Darussalam          1101
# 5                11  Prov. Nanggroe Aceh Darussalam          1102
# 6                11  Prov. Nanggroe Aceh Darussalam          1102
# 7                11  Prov. Nanggroe Aceh Darussalam          1102
# 8                11  Prov. Nanggroe Aceh Darussalam          1102
# 9                11  Prov. Nanggroe Aceh Darussalam          1102
# 10               11  Prov. Nanggroe Aceh Darussalam          1103
# 11               11  Prov. Nanggroe Aceh Darussalam          1103
# 12               11  Prov. Nanggroe Aceh Darussalam          1103
# ...

# %%
data_amh.columns
# Out:
# Index(['kode_provinsi', 'nama_provinsi', 'kode_kabkota', 'nama_kabkota',
#        'tahun', 'angka_melek_huruf'],
#       dtype='object')

# %%
data_amh.head()
# Out:
#    kode_provinsi                   nama_provinsi  kode_kabkota   nama_kabkota  \
# 0             11  Prov. Nanggroe Aceh Darussalam          1101  Kab. Simeulue
# 1             11  Prov. Nanggroe Aceh Darussalam          1101  Kab. Simeulue
# 2             11  Prov. Nanggroe Aceh Darussalam          1101  Kab. Simeulue
# 3             11  Prov. Nanggroe Aceh Darussalam          1101  Kab. Simeulue
# 4             11  Prov. Nanggroe Aceh Darussalam          1101  Kab. Simeulue
#
#    tahun  angka_melek_huruf
# 0   2005              98.39
# 1   2006              99.30
# 2   2007              99.28
# 3   2008              99.68
# 4   2009             100.00

# %%
data_amh.sample(5)
# Out:
#       kode_provinsi         nama_provinsi  kode_kabkota       nama_kabkota  \
# 2104             76  Prov. Sulawesi Barat          7603        Kab. Mamasa
# 318              13  Prov. Sumatera Barat          1371        Kota Padang
# 871              33     Prov. Jawa Tengah          3304  Kab. Banjarnegara
# 738              32      Prov. Jawa Barat          3203       Kab. Cianjur
# 1107             35      Prov. Jawa Timur          3511     Kab. Bondowoso
#
#       tahun  angka_melek_huruf
# 2104   2009              95.30
# 318    2008              99.89
# 871    2006              98.87
# 738    2008             100.00
# 1107   2007              96.63

# %%
data_amh_jatim = data_amh[data_amh['nama_provinsi']=='Prov. Jawa Timur']

# %%
data_amh_jatim
# Out:
#       kode_provinsi     nama_provinsi  kode_kabkota      nama_kabkota  tahun  \
# 1055             35  Prov. Jawa Timur          3501      Kab. Pacitan   2005
# 1056             35  Prov. Jawa Timur          3501      Kab. Pacitan   2006
# 1057             35  Prov. Jawa Timur          3501      Kab. Pacitan   2007
# 1058             35  Prov. Jawa Timur          3501      Kab. Pacitan   2008
# 1059             35  Prov. Jawa Timur          3501      Kab. Pacitan   2009
# 1060             35  Prov. Jawa Timur          3502     Kab. Ponorogo   2005
# 1061             35  Prov. Jawa Timur          3502     Kab. Ponorogo   2006
# 1062             35  Prov. Jawa Timur          3502     Kab. Ponorogo   2007
# 1063             35  Prov. Jawa Timur          3502     Kab. Ponorogo   2008
# 1064             35  Prov. Jawa Timur          3502     Kab. Ponorogo   2009
# 1065             35  Prov. Jawa Timur          3503   Kab. Trenggalek   2005
# ...
