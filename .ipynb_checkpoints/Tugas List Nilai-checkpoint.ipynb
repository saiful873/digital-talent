# %% [markdown]
# # LATIHAN 2 - Tugas List Nilai
#
# Diberikan sekumpulan Nilai Random antara 0 sampai dengan 100 sebanyak 250 nilai. Buatlah program untuk melakukan hal berikut:
# 1. Tampilkan Angka Ganjil dari ke 250 nilai tersebut
# 2. Tampilkan berapa banyak yang mendapatkan nilai lebih dari 70
# 3. Tampilkan standar deviasi dari sekumpulan nilai tersebut
# 4. Tampilkan nilai maksimum dan minimum
# 5. Tampilkan modus dari sekumpulan nilai tersebut

# %%
import random

# Generate Random untuk List NilaiTugas
NilaiTugas = []
for i in range (250):
    NilaiTugas.append(random.randrange(1,100,1))
    
print(NilaiTugas)
# Out:
# [40, 23, 88, 77, 47, 94, 57, 64, 75, 53, 41, 80, 90, 96, 85, 52, 23, 39, 13, 98, 50, 4, 33, 84, 21, 42, 61, 97, 96, 18, 12, 1, 3, 71, 2, 57, 55, 35, 39, 24, 93, 99, 51, 83, 92, 62, 3, 75, 6, 82, 1, 91, 75, 97, 28, 55, 57, 38, 51, 7, 41, 19, 64, 1, 34, 96, 84, 40, 34, 60, 49, 72, 88, 44, 67, 77, 22, 94, 91, 49, 96, 90, 94, 53, 68, 60, 73, 45, 78, 42, 75, 65, 85, 59, 47, 89, 17, 8, 59, 31, 41, 25, 80, 23, 37, 62, 51, 4, 80, 8, 92, 64, 33, 83, 86, 17, 6, 37, 55, 65, 21, 19, 20, 58, 50, 59, 99, 45, 94, 62, 88, 50, 79, 64, 26, 52, 76, 67, 32, 63, 88, 19, 19, 31, 14, 30, 38, 45, 64, 96, 89, 85, 49, 54, 98, 57, 75, 21, 78, 85, 92, 78, 68, 84, 41, 24, 84, 81, 33, 12, 4, 46, 40, 77, 95, 67, 82, 45, 27, 64, 37, 56, 31, 40, 98, 1, 65, 4, 15, 48, 56, 52, 35, 82, 97, 32, 95, 57, 95, 17, 30, 72, 19, 18, 61, 94, 74, 86, 7, 69, 27, 84, 49, 21, 57, 15, 9, 88, 94, 99, 61, 48, 3, 87, 61, 43, 11, 59, 18, 10, 3, 97, 76, 31, 22, 96, 58, 97, 1, 75, 91, 61, 32, 35, 32, 99, 38, 29, 15, 48]

# %% [markdown]
# ### 1. Menampilkan  Angka Ganjil dari List Nilai Tugas

# %%
for i in NilaiTugas:
    if i%2 !=0:
        print(i)
# Out:
# 23
# 77
# 47
# 57
# 75
# 53
# 41
# 85
# 23
# 39
# 13
# 33
# 21
# 61
# 97
# 1
# 3
# 71
# 57
# 55
# 35
# 39
# 93
# 99
# 51
# 83
# 3
# 75
# 1
# 91
# 75
# 97
# 55
# 57
# 51
# 7
# 41
# 19
# 1
# 49
# 67
# 77
# 91
# 49
# 53
# 73
# 45
# 75
# 65
# 85
# 59
# 47
# 89
# 17
# 59
# 31
# 41
# 25
# 23
# 37
# 51
# 33
# 83
# 17
# 37
# 55
# 65
# 21
# 19
# 59
# 99
# 45
# 79
# 67
# 63
# 19
# 19
# 31
# 45
# 89
# 85
# 49
# 57
# 75
# 21
# 85
# 41
# 81
# 33
# 77
# 95
# 67
# 45
# 27
# 37
# 31
# 1
# 65
# 15
# 35
# 97
# 95
# 57
# 95
# 17
# 19
# 61
# 7
# 69
# 27
# 49
# 21
# 57
# 15
# 9
# 99
# 61
# 3
# 87
# 61
# 43
# 11
# 59
# 3
# 97
# 31
# 97
# 1
# 75
# 91
# 61
# 35
# 99
# 29
# 15

# %% [markdown]
# ### 2. Menampilkan Nilai yang Lebih dari 70 ( > 70)

# %%
for i in NilaiTugas:
    if i > 70:
        print(i)
# Out:
# 88
# 77
# 94
# 75
# 80
# 90
# 96
# 85
# 98
# 84
# 97
# 96
# 71
# 93
# 99
# 83
# 92
# 75
# 82
# 91
# 75
# 97
# 96
# 84
# 72
# 88
# 77
# 94
# 91
# 96
# 90
# 94
# 73
# 78
# 75
# 85
# 89
# 80
# 80
# 92
# 83
# 86
# 99
# 94
# 88
# 79
# 76
# 88
# 96
# 89
# 85
# 98
# 75
# 78
# 85
# 92
# 78
# 84
# 84
# 81
# 77
# 95
# 82
# 98
# 82
# 97
# 95
# 95
# 72
# 94
# 74
# 86
# 84
# 88
# 94
# 99
# 87
# 97
# 76
# 96
# 97
# 75
# 91
# 99

# %% [markdown]
# ### 3. Menampilkan Standar Deviasi dari List NilaiTugas

# %%
# Salah satu yang dibutuhkan dalam menghitung standar deviasi adalah nilai rata-rata

#langkah 1, menjumlahkan seluruh nilai dalam List
totalNilaiTugas = 0
for i in NilaiTugas:
    totalNilaiTugas = totalNilaiTugas + i
print("Hasil jumlah seluruh nilai di dalam List NilaiTugas adalah", totalNilaiTugas)
    
# m_NilaiTugas = totalNilaiTugas / len(NilaiTugas)
# print("dengan nilai rata-rata", m_NilaiTugas)

# langkah 2, memangkatkan dua hasil penjumlahan sebelumnya
totalNilaiTugas_2 = totalNilaiTugas ** 2
print("Hasil pangkat dua dari jumlah seluruh nilai di dalam List NilaiTugas adalah", totalNilaiTugas_2)

# langkah 3, memangkatkan dua setiap nilai dalam list
NilaiTugas2 = []
for i in NilaiTugas:
    NilaiTugas2.append(i**2)
# print(NilaiTugas2)

# Langkah 4, menjumlahkan seluruh hasil pemangkatan dua nilai dalam list
total_NilaiTugas2 = 0
for i in NilaiTugas2:
    total_NilaiTugas2 = total_NilaiTugas2 + i
print("Hasil jumlah seluruh nilai di dalam List NilaiTugas yang telah dipangkatkan adalah", total_NilaiTugas2)

# print(type(totalNilaiTugas_2))
# print(type(total_NilaiTugas2))

#langkah 4, Nilai varian
n = len(NilaiTugas)

varian_NilaiTugas = ((n*total_NilaiTugas2) - totalNilaiTugas_2) / (n*(n-1))
print("Varian dari kumpulan nilai dalam List adalah ", varian_NilaiTugas)

#langkah 5, Standar deviasi merupakan akar kuadrat dari varian
s_NilaiTugas = varian_NilaiTugas ** 0.5
print("Standar deviasi dari kumpulan nilai dalam list adalah", s_NilaiTugas)
# Out:
# Hasil jumlah seluruh nilai di dalam List NilaiTugas adalah 13421
# Hasil pangkat dua dari jumlah seluruh nilai di dalam List NilaiTugas adalah 180123241
# Hasil jumlah seluruh nilai di dalam List NilaiTugas yang telah dipangkatkan adalah 931615
# Varian dari kumpulan nilai dalam List adalah  847.8796626506024
# Standar deviasi dari kumpulan nilai dalam list adalah 29.118373283042487

# %% [markdown]
# ### 4. Menampilkan Nilai Maksimum dan Minimum Nilai dalam List

# %%
maksimum = NilaiTugas[0] # n = len(NilaiTugas)
for i in NilaiTugas:
    if i > maksimum:
        maksimum = i
        print(maksimum)
print("Nilai maksimumnya adalah", maksimum)

minimum = NilaiTugas[0]
for i in NilaiTugas:
    if i < minimum:
        minimum = i
        print(minimum)
print("Nilai minimumnya adalah", minimum)
# Out:
# 88
# 94
# 96
# 98
# 99
# Nilai maksimumnya adalah 99
# 23
# 13
# 4
# 1
# Nilai minimumnya adalah 1

# %% [markdown]
# ### 5. Menampilkan Modus dari Sekumpulan Nilai dalam List

# %%
# frekuensi
frekuensi = {}
for i in NilaiTugas:
    frekuensi[i] = frekuensi.get(i, 0) + 1
    
print(frekuensi)

# mode
for k,v in frekuensi.items():
        print(k,":",v)
# Out:
# {40: 4, 23: 3, 88: 5, 77: 3, 47: 2, 94: 6, 57: 6, 64: 6, 75: 6, 53: 2, 41: 4, 80: 3, 90: 2, 96: 6, 85: 4, 52: 3, 39: 2, 13: 1, 98: 3, 50: 3, 4: 4, 33: 3, 84: 5, 21: 4, 42: 2, 61: 5, 97: 5, 18: 3, 12: 2, 1: 5, 3: 4, 71: 1, 2: 1, 55: 3, 35: 3, 24: 2, 93: 1, 99: 4, 51: 3, 83: 2, 92: 3, 62: 3, 6: 2, 82: 3, 91: 3, 28: 1, 38: 3, 7: 2, 19: 5, 34: 2, 60: 2, 49: 4, 72: 2, 44: 1, 67: 3, 22: 2, 68: 2, 73: 1, 45: 4, 78: 3, 65: 3, 59: 4, 89: 2, 17: 3, 8: 2, 31: 4, 25: 1, 37: 3, 86: 2, 20: 1, 58: 2, 79: 1, 26: 1, 76: 2, 32: 4, 63: 1, 14: 1, 30: 2, 54: 1, 81: 1, 46: 1, 95: 3, 27: 2, 56: 2, 15: 3, 48: 3, 74: 1, 69: 1, 9: 1, 87: 1, 43: 1, 11: 1, 10: 1, 29: 1}
# 40 : 4
# 23 : 3
# 88 : 5
# 77 : 3
# 47 : 2
# 94 : 6
# 57 : 6
# 64 : 6
# 75 : 6
# 53 : 2
# 41 : 4
# 80 : 3
# 90 : 2
# 96 : 6
# 85 : 4
# 52 : 3
# 39 : 2
# 13 : 1
# 98 : 3
# 50 : 3
# 4 : 4
# 33 : 3
# 84 : 5
# 21 : 4
# 42 : 2
# 61 : 5
# 97 : 5
# 18 : 3
# 12 : 2
# 1 : 5
# 3 : 4
# 71 : 1
# 2 : 1
# 55 : 3
# 35 : 3
# 24 : 2
# 93 : 1
# 99 : 4
# 51 : 3
# 83 : 2
# 92 : 3
# 62 : 3
# 6 : 2
# 82 : 3
# 91 : 3
# 28 : 1
# 38 : 3
# 7 : 2
# 19 : 5
# 34 : 2
# 60 : 2
# 49 : 4
# 72 : 2
# 44 : 1
# 67 : 3
# 22 : 2
# 68 : 2
# 73 : 1
# 45 : 4
# 78 : 3
# 65 : 3
# 59 : 4
# 89 : 2
# 17 : 3
# 8 : 2
# 31 : 4
# 25 : 1
# 37 : 3
# 86 : 2
# 20 : 1
# 58 : 2
# 79 : 1
# 26 : 1
# 76 : 2
# 32 : 4
# 63 : 1
# 14 : 1
# 30 : 2
# 54 : 1
# 81 : 1
# 46 : 1
# 95 : 3
# 27 : 2
# 56 : 2
# 15 : 3
# 48 : 3
# 74 : 1
# 69 : 1
# 9 : 1
# 87 : 1
# 43 : 1
# 11 : 1
# 10 : 1
# 29 : 1
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-e4ce35fee5c4> in <module>()
#      10         print(k,":",v)
#      11
# ---> 12 maksimum_frek = max(frekuensi.itervalue())
#
# AttributeError: 'dict' object has no attribute 'itervalue'
