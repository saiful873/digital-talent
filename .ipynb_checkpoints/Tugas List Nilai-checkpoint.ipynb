# %% [markdown]
# # LATIHAN 2 - Tugas List Nilai
#
# Diberikan sekumpulan Nilai Random antara 0 sampai dengan 100 sebanyak 250 nilai. Buatlah program untuk melakukan hal berikut:
# 1. Tampilkan Angka Ganjil dari ke 250 nilai tersebut
# 2. Tampilkan berapa banyak yang mendapatkan nilai lebih dari 70
# 3. Tampilkan standar deviasi dari sekumpulan nilai tersebut
# 4. Tampilkan nilai maksimum dan minimum
# 5. Tampilkan modus dari sekumpulan nilai tersebut

# %%
import random

# Generate Random untuk List NilaiTugas
NilaiTugas = []
for i in range (250):
    NilaiTugas.append(random.randrange(1,100,1))
    
print(NilaiTugas)
# Out:
# [29, 75, 75, 30, 63, 67, 96, 64, 81, 1, 36, 2, 35, 69, 52, 94, 46, 19, 13, 10, 49, 44, 81, 83, 75, 88, 73, 12, 77, 73, 58, 81, 89, 87, 88, 29, 48, 27, 84, 58, 11, 15, 12, 32, 24, 19, 61, 5, 31, 44, 48, 58, 75, 80, 57, 62, 72, 51, 93, 8, 47, 11, 99, 69, 80, 64, 46, 85, 67, 43, 4, 84, 61, 92, 74, 31, 20, 36, 90, 55, 20, 69, 91, 66, 83, 45, 40, 39, 86, 87, 26, 70, 57, 51, 81, 47, 59, 75, 1, 19, 68, 99, 99, 97, 34, 38, 27, 87, 76, 51, 62, 22, 94, 40, 81, 29, 12, 75, 82, 30, 18, 22, 36, 10, 63, 54, 7, 99, 98, 70, 42, 55, 95, 59, 9, 28, 19, 19, 70, 76, 52, 87, 59, 21, 23, 76, 75, 32, 86, 67, 11, 47, 6, 63, 79, 31, 67, 32, 21, 57, 1, 17, 32, 78, 39, 62, 43, 91, 38, 67, 16, 36, 8, 86, 62, 30, 86, 95, 7, 39, 37, 18, 66, 85, 44, 51, 55, 38, 48, 73, 56, 2, 21, 13, 73, 25, 57, 50, 12, 42, 85, 93, 68, 86, 59, 92, 19, 87, 79, 54, 34, 85, 48, 49, 55, 44, 12, 1, 76, 80, 74, 13, 11, 86, 4, 45, 45, 62, 81, 2, 78, 6, 92, 51, 27, 47, 33, 48, 76, 76, 15, 2, 88, 16, 72, 51, 96, 71, 72, 66]

# %% [markdown]
# ### 1. Menampilkan  Angka Ganjil dari List Nilai Tugas

# %%
for i in NilaiTugas:
    if i%2 !=0:
        print(i)
# Out:
# 29
# 75
# 75
# 63
# 67
# 81
# 1
# 35
# 69
# 19
# 13
# 49
# 81
# 83
# 75
# 73
# 77
# 73
# 81
# 89
# 87
# 29
# 27
# 11
# 15
# 19
# 61
# 5
# 31
# 75
# 57
# 51
# 93
# 47
# 11
# 99
# 69
# 85
# 67
# 43
# 61
# 31
# 55
# 69
# 91
# 83
# 45
# 39
# 87
# 57
# 51
# 81
# 47
# 59
# 75
# 1
# 19
# 99
# 99
# 97
# 27
# 87
# 51
# 81
# 29
# 75
# 63
# 7
# 99
# 55
# 95
# 59
# 9
# 19
# 19
# 87
# 59
# 21
# 23
# 75
# 67
# 11
# 47
# 63
# 79
# 31
# 67
# 21
# 57
# 1
# 17
# 39
# 43
# 91
# 67
# 95
# 7
# 39
# 37
# 85
# 51
# 55
# 73
# 21
# 13
# 73
# 25
# 57
# 85
# 93
# 59
# 19
# 87
# 79
# 85
# 49
# 55
# 1
# 13
# 11
# 45
# 45
# 81
# 51
# 27
# 47
# 33
# 15
# 51
# 71

# %% [markdown]
# ### 2. Menampilkan Nilai yang Lebih dari 70 ( > 70)

# %%
for i in NilaiTugas:
    if i > 70:
        print(i)
# Out:
# 75
# 75
# 96
# 81
# 94
# 81
# 83
# 75
# 88
# 73
# 77
# 73
# 81
# 89
# 87
# 88
# 84
# 75
# 80
# 72
# 93
# 99
# 80
# 85
# 84
# 92
# 74
# 90
# 91
# 83
# 86
# 87
# 81
# 75
# 99
# 99
# 97
# 87
# 76
# 94
# 81
# 75
# 82
# 99
# 98
# 95
# 76
# 87
# 76
# 75
# 86
# 79
# 78
# 91
# 86
# 86
# 95
# 85
# 73
# 73
# 85
# 93
# 86
# 92
# 87
# 79
# 85
# 76
# 80
# 74
# 86
# 81
# 78
# 92
# 76
# 76
# 88
# 72
# 96
# 71
# 72

# %% [markdown]
# ### 3. Menampilkan Standar Deviasi dari List NilaiTugas

# %%
# Salah satu yang dibutuhkan dalam menghitung standar deviasi adalah nilai rata-rata

#langkah 1, menjumlahkan seluruh nilai dalam List
totalNilaiTugas = 0
for i in NilaiTugas:
    totalNilaiTugas = totalNilaiTugas + i
print("Hasil jumlah seluruh nilai di dalam List NilaiTugas adalah", totalNilaiTugas)
    
# m_NilaiTugas = totalNilaiTugas / len(NilaiTugas)
# print("dengan nilai rata-rata", m_NilaiTugas)

# langkah 2, memangkatkan dua hasil penjumlahan sebelumnya
totalNilaiTugas_2 = totalNilaiTugas ** 2
print("Hasil pangkat dua dari jumlah seluruh nilai di dalam List NilaiTugas adalah", totalNilaiTugas_2)

# langkah 3, memangkatkan dua setiap nilai dalam list
NilaiTugas2 = []
for i in NilaiTugas:
    NilaiTugas2.append(i**2)
# print(NilaiTugas2)

# Langkah 4, menjumlahkan seluruh hasil pemangkatan dua nilai dalam list
total_NilaiTugas2 = 0
for i in NilaiTugas2:
    total_NilaiTugas2 = total_NilaiTugas2 + i
print("Hasil jumlah seluruh nilai di dalam List NilaiTugas yang telah dipangkatkan adalah", total_NilaiTugas2)

# print(type(totalNilaiTugas_2))
# print(type(total_NilaiTugas2))

#langkah 4, Nilai varian
n = len(NilaiTugas)

varian_NilaiTugas = ((n*total_NilaiTugas2) - totalNilaiTugas_2) / (n*(n-1))
print("Varian dari kumpulan nilai dalam List adalah ", varian_NilaiTugas)

#langkah 5, Standar deviasi merupakan akar kuadrat dari varian
s_NilaiTugas = varian_NilaiTugas ** 0.5
print("Standar deviasi dari kumpulan nilai dalam list adalah", s_NilaiTugas)
# Out:
# Hasil jumlah seluruh nilai di dalam List NilaiTugas adalah 13044
# Hasil pangkat dua dari jumlah seluruh nilai di dalam List NilaiTugas adalah 170145936
# Hasil jumlah seluruh nilai di dalam List NilaiTugas yang telah dipangkatkan adalah 875558
# Varian dari kumpulan nilai dalam List adalah  783.029140562249
# Standar deviasi dari kumpulan nilai dalam list adalah 27.982657853789533

# %% [markdown]
# ### 4. Menampilkan Nilai Maksimum dan Minimum Nilai dalam List

# %%
maksimum = NilaiTugas[0] # n = len(NilaiTugas)
for i in NilaiTugas:
    if i > maksimum:
        maksimum = i
        print(maksimum)
print("Nilai maksimumnya adalah", maksimum)

minimum = NilaiTugas[0]
for i in NilaiTugas:
    if i < minimum:
        minimum = i
        print(minimum)
print("Nilai minimumnya adalah", minimum)
# Out:
# 75
# 96
# 99
# Nilai maksimumnya adalah 99
# 1
# Nilai minimumnya adalah 1

# %% [markdown]
# ### 5. Menampilkan Modus dari Sekumpulan Nilai dalam List

# %%
# frekuensi
frekuensi = {}
for i in NilaiTugas:
    frekuensi[i] = frekuensi.get(i, 0) + 1
    
print(frekuensi)
print("======")

# mode
for k,v in frekuensi.items():
        print(k,":",v)
        
print("======")
        
modus = max((v, k) for k, v in frekuensi.items())
print("Nilai modus dari List adalah", modus[1], "dengan jumlah frekuensi nilai keluar", modus[0])
# Out:
# {29: 3, 75: 7, 30: 3, 63: 3, 67: 5, 96: 2, 64: 2, 81: 6, 1: 4, 36: 4, 2: 4, 35: 1, 69: 3, 52: 2, 94: 2, 46: 2, 19: 6, 13: 3, 10: 2, 49: 2, 44: 4, 83: 2, 88: 3, 73: 4, 12: 5, 77: 1, 58: 3, 89: 1, 87: 5, 48: 5, 27: 3, 84: 2, 11: 4, 15: 2, 32: 4, 24: 1, 61: 2, 5: 1, 31: 3, 80: 3, 57: 4, 62: 5, 72: 3, 51: 6, 93: 2, 8: 2, 47: 4, 99: 4, 85: 4, 43: 2, 4: 2, 92: 3, 74: 2, 20: 2, 90: 1, 55: 4, 91: 2, 66: 3, 45: 3, 40: 2, 39: 3, 86: 6, 26: 1, 70: 3, 59: 4, 68: 2, 97: 1, 34: 2, 38: 3, 76: 6, 22: 2, 82: 1, 18: 2, 54: 2, 7: 2, 98: 1, 42: 2, 95: 2, 9: 1, 28: 1, 21: 3, 23: 1, 6: 2, 79: 2, 17: 1, 78: 2, 16: 2, 37: 1, 56: 1, 25: 1, 50: 1, 33: 1, 71: 1}
# ======
# 29 : 3
# 75 : 7
# 30 : 3
# 63 : 3
# 67 : 5
# 96 : 2
# 64 : 2
# 81 : 6
# 1 : 4
# 36 : 4
# 2 : 4
# 35 : 1
# 69 : 3
# 52 : 2
# 94 : 2
# 46 : 2
# 19 : 6
# 13 : 3
# 10 : 2
# 49 : 2
# 44 : 4
# 83 : 2
# 88 : 3
# 73 : 4
# 12 : 5
# 77 : 1
# 58 : 3
# 89 : 1
# 87 : 5
# 48 : 5
# 27 : 3
# 84 : 2
# 11 : 4
# 15 : 2
# 32 : 4
# 24 : 1
# 61 : 2
# 5 : 1
# 31 : 3
# 80 : 3
# 57 : 4
# 62 : 5
# 72 : 3
# 51 : 6
# 93 : 2
# 8 : 2
# 47 : 4
# 99 : 4
# 85 : 4
# 43 : 2
# 4 : 2
# 92 : 3
# 74 : 2
# 20 : 2
# 90 : 1
# 55 : 4
# 91 : 2
# 66 : 3
# 45 : 3
# 40 : 2
# 39 : 3
# 86 : 6
# 26 : 1
# 70 : 3
# 59 : 4
# 68 : 2
# 97 : 1
# 34 : 2
# 38 : 3
# 76 : 6
# 22 : 2
# 82 : 1
# 18 : 2
# 54 : 2
# 7 : 2
# 98 : 1
# 42 : 2
# 95 : 2
# 9 : 1
# 28 : 1
# 21 : 3
# 23 : 1
# 6 : 2
# 79 : 2
# 17 : 1
# 78 : 2
# 16 : 2
# 37 : 1
# 56 : 1
# 25 : 1
# 50 : 1
# 33 : 1
# 71 : 1
# ======
# Nilai modus dari List adalah 75 dengan jumlah frekuensi nilai keluar 7
