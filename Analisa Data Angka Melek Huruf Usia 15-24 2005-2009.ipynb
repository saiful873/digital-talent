# %%
import pandas as pd

# %%
data_amh = pd.read_csv('processed-angka-melek-huruf-usia-15-24-2005-2009.csv', delimiter = ',', encoding = "utf-8")

# %%
data_amh
# Out:
#       kode_provinsi                   nama_provinsi  kode_kabkota  \
# 0                11  Prov. Nanggroe Aceh Darussalam          1101
# 1                11  Prov. Nanggroe Aceh Darussalam          1101
# 2                11  Prov. Nanggroe Aceh Darussalam          1101
# 3                11  Prov. Nanggroe Aceh Darussalam          1101
# 4                11  Prov. Nanggroe Aceh Darussalam          1101
# 5                11  Prov. Nanggroe Aceh Darussalam          1102
# 6                11  Prov. Nanggroe Aceh Darussalam          1102
# 7                11  Prov. Nanggroe Aceh Darussalam          1102
# 8                11  Prov. Nanggroe Aceh Darussalam          1102
# 9                11  Prov. Nanggroe Aceh Darussalam          1102
# 10               11  Prov. Nanggroe Aceh Darussalam          1103
# 11               11  Prov. Nanggroe Aceh Darussalam          1103
# 12               11  Prov. Nanggroe Aceh Darussalam          1103
# ...

# %%
data_amh.columns
# Out:
# Index(['kode_provinsi', 'nama_provinsi', 'kode_kabkota', 'nama_kabkota',
#        'tahun', 'angka_melek_huruf'],
#       dtype='object')

# %%
data_amh.head()
# Out:
#    kode_provinsi                   nama_provinsi  kode_kabkota   nama_kabkota  \
# 0             11  Prov. Nanggroe Aceh Darussalam          1101  Kab. Simeulue
# 1             11  Prov. Nanggroe Aceh Darussalam          1101  Kab. Simeulue
# 2             11  Prov. Nanggroe Aceh Darussalam          1101  Kab. Simeulue
# 3             11  Prov. Nanggroe Aceh Darussalam          1101  Kab. Simeulue
# 4             11  Prov. Nanggroe Aceh Darussalam          1101  Kab. Simeulue
#
#    tahun  angka_melek_huruf
# 0   2005              98.39
# 1   2006              99.30
# 2   2007              99.28
# 3   2008              99.68
# 4   2009             100.00

# %%
data_amh.sample(100)
# Out:
#       kode_provinsi                    nama_provinsi  kode_kabkota  \
# 896              33                Prov. Jawa Tengah          3309
# 1324             51                       Prov. Bali          5171
# 1518             61           Prov. Kalimantan Barat          6110
# 1124             35                 Prov. Jawa Timur          3514
# 352              14                       Prov. Riau          1401
# 1110             35                 Prov. Jawa Timur          3512
# 680              21             Prov. Kepulauan Riau          2104
# 656              19  Prov. Kepulauan Bangka Belitung          1906
# 1353             52        Prov. Nusa Tenggara Barat          5206
# 644              19  Prov. Kepulauan Bangka Belitung          1903
# 1357             52        Prov. Nusa Tenggara Barat          5207
# 974              33                Prov. Jawa Tengah          3324
# 836              32                 Prov. Jawa Barat          3276
# ...

# %%
data_amh_jatim = data_amh[data_amh['nama_provinsi']=='Prov. Jawa Timur']

# %%
data_amh_jatim
# Out:
#       kode_provinsi     nama_provinsi  kode_kabkota      nama_kabkota  tahun  \
# 1055             35  Prov. Jawa Timur          3501      Kab. Pacitan   2005
# 1056             35  Prov. Jawa Timur          3501      Kab. Pacitan   2006
# 1057             35  Prov. Jawa Timur          3501      Kab. Pacitan   2007
# 1058             35  Prov. Jawa Timur          3501      Kab. Pacitan   2008
# 1059             35  Prov. Jawa Timur          3501      Kab. Pacitan   2009
# 1060             35  Prov. Jawa Timur          3502     Kab. Ponorogo   2005
# 1061             35  Prov. Jawa Timur          3502     Kab. Ponorogo   2006
# 1062             35  Prov. Jawa Timur          3502     Kab. Ponorogo   2007
# 1063             35  Prov. Jawa Timur          3502     Kab. Ponorogo   2008
# 1064             35  Prov. Jawa Timur          3502     Kab. Ponorogo   2009
# 1065             35  Prov. Jawa Timur          3503   Kab. Trenggalek   2005
# ...

# %%
data_amh_jatim[data_amh_jatim['tahun'] == 2007]
# Out:
#       kode_provinsi     nama_provinsi  kode_kabkota      nama_kabkota  tahun  \
# 1057             35  Prov. Jawa Timur          3501      Kab. Pacitan   2007
# 1062             35  Prov. Jawa Timur          3502     Kab. Ponorogo   2007
# 1067             35  Prov. Jawa Timur          3503   Kab. Trenggalek   2007
# 1072             35  Prov. Jawa Timur          3504  Kab. Tulungagung   2007
# 1077             35  Prov. Jawa Timur          3505       Kab. Blitar   2007
# 1082             35  Prov. Jawa Timur          3506       Kab. Kediri   2007
# 1087             35  Prov. Jawa Timur          3507       Kab. Malang   2007
# 1092             35  Prov. Jawa Timur          3508     Kab. Lumajang   2007
# 1097             35  Prov. Jawa Timur          3509       Kab. Jember   2007
# 1102             35  Prov. Jawa Timur          3510   Kab. Banyuwangi   2007
# 1107             35  Prov. Jawa Timur          3511    Kab. Bondowoso   2007
# ...

# %%
data_amh_2009 = data_amh[data_amh['tahun'] == 2009]

# %%
data_amh_2009
# Out:
#       kode_provinsi                   nama_provinsi  kode_kabkota  \
# 4                11  Prov. Nanggroe Aceh Darussalam          1101
# 9                11  Prov. Nanggroe Aceh Darussalam          1102
# 14               11  Prov. Nanggroe Aceh Darussalam          1103
# 19               11  Prov. Nanggroe Aceh Darussalam          1104
# 24               11  Prov. Nanggroe Aceh Darussalam          1105
# 29               11  Prov. Nanggroe Aceh Darussalam          1106
# 34               11  Prov. Nanggroe Aceh Darussalam          1107
# 39               11  Prov. Nanggroe Aceh Darussalam          1108
# 44               11  Prov. Nanggroe Aceh Darussalam          1109
# 49               11  Prov. Nanggroe Aceh Darussalam          1110
# 54               11  Prov. Nanggroe Aceh Darussalam          1111
# 59               11  Prov. Nanggroe Aceh Darussalam          1112
# 64               11  Prov. Nanggroe Aceh Darussalam          1113
# ...

# %%
data_amh.groupby(['tahun']).mean()
# Out:
#        kode_provinsi  kode_kabkota  angka_melek_huruf
# tahun
# 2005       45.634855   4585.255187          86.953610
# 2006       45.634855   4585.255187          88.988195
# 2007       45.634855   4585.255187          92.250290
# 2008       45.634855   4585.255187          93.373506
# 2009       45.634855   4585.255187          95.005166

# %%
ig = data_amh.groupby(['tahun']).mean()['angka_melek_huruf']
ig = ig.plot(kind='line', title ="Rata-Rata Berdasarkan Tahun", figsize=(10,10), legend=True, fontsize=12)
ig.set_xlabel("Tahun", fontsize=12)
ig.set_ylabel("AMH", fontsize=12)
# Out:
# Text(0,0.5,'AMH')
